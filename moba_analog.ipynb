# %% [markdown]
# # **Scrapping data with google playstore**
#
# # ***APP Mobile Legends Content Sentiment Analysis Using NLP and K-Means***

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.0 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %% [markdown]
# **Scrape desired number of reviews**

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.mobile.legends', #link app store
    lang = 'id', #defaults to 'en'
    country = 'id', #defaults to 'us'
    sort = Sort.NEWEST, #get data newest
    count = 300, #defaults get try 300 data
    filter_score_with = None #defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

# %%
#import pandas and numpy
import pandas as pd
import numpy as np

df_busu = pd.DataFrame(np.array(result), columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head(10)
# Out:
#                                reviewId                   userName  \
# 0  6370bfc6-b60f-4270-9da6-97e362ea3a3b                    Akun ML
# 1  3db1ca02-f19f-4a7a-83cc-f1bc4d5b5d7f  Davit Freedom Sindangsari
# 2  648a2390-7bda-4272-b656-447887ea49cc               chia• grilTM
# 3  cae3cf44-f23e-4ac4-bbea-8e4d7925748a                  Ahza Ahza
# 4  46aeb261-5a72-4d0a-b7de-c62ba2ba29ab                     ᴊɪᴍᴍʏツ
# 5  3901188d-611e-4f7a-830d-10ba8dd47c9e                 Arull Ajaa
# 6  fdd01dbb-6b09-4771-a7bf-0e74bab6d6d2                    Mar Kdi
# 7  cf5ef11f-ab85-425c-9747-fa39cd2a29d3                  Juan Juan
# 8  661266fd-8882-45a7-b4c9-2fa14292f26d                Nanda Nanda
# 9  7748312d-49b2-47ed-acd9-52314e32d21a                 Riko Ricko
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
# 5  https://play-lh.googleusercontent.com/a-/ALV-U...
# 6  https://play-lh.googleusercontent.com/a-/ALV-U...
# 7  https://play-lh.googleusercontent.com/a/ACg8oc...
# 8  https://play-lh.googleusercontent.com/a-/ALV-U...
# 9  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0                        game rajelas, moonton janck      1              0
# 1  Knph sich sekarang mh sering erorr mobile lege...      5              0
# 2  game ini sangat cocok untuk saya.saya suka ban...      5              0
# 3         sudah ngepick hero malah diganti hero lain      1              0
# 4  monton ngasih musuh itu yang cupu dikit lah ka...      1              0
# 5  makin update makin ga jelas ni game jaringan f...      1              0
# 6  minimal punya fitur deteksi jaringan buruk mas...      3              0
# 7  JANGAN DOWNLOAD GAME INI JIKA ANDA TIDAK INGIN...      1              0
# 8  Game bagus, ini game yg dlu saya mainkan dari ...      5              0
# 9                                              bagus      5              0
#
#   reviewCreatedVersion                  at replyContent repliedAt  \
# 0           1.9.8.9833 2025-04-26 03:20:23         None       NaT
# 1          1.6.72.7351 2025-04-26 03:19:51         None       NaT
# 2                 None 2025-04-26 03:18:01         None       NaT
# 3         1.9.68.10631 2025-04-26 03:15:06         None       NaT
# 4         1.9.68.10631 2025-04-26 03:13:54         None       NaT
# 5         1.9.64.10601 2025-04-26 03:13:46         None       NaT
# 6         1.9.68.10631 2025-04-26 03:13:18         None       NaT
# 7         1.9.68.10631 2025-04-26 03:13:13         None       NaT
# 8          1.6.35.6931 2025-04-26 03:12:47         None       NaT
# 9         1.9.68.10631 2025-04-26 03:12:18         None       NaT
#
#      appVersion
# 0    1.9.8.9833
# 1   1.6.72.7351
# 2          None
# 3  1.9.68.10631
# 4  1.9.68.10631
# 5  1.9.64.10601
# 6  1.9.68.10631
# 7  1.9.68.10631
# 8   1.6.35.6931
# 9  1.9.68.10631

# %%
#check for get data
len(df_busu.index)
# Out:
# 300

# %%
df_busu[['userName', 'score', 'at', 'content']].head(10)
# Out:
#                     userName  score                  at  \
# 0                    Akun ML      1 2025-04-26 03:20:23
# 1  Davit Freedom Sindangsari      5 2025-04-26 03:19:51
# 2               chia• grilTM      5 2025-04-26 03:18:01
# 3                  Ahza Ahza      1 2025-04-26 03:15:06
# 4                     ᴊɪᴍᴍʏツ      1 2025-04-26 03:13:54
# 5                 Arull Ajaa      1 2025-04-26 03:13:46
# 6                    Mar Kdi      3 2025-04-26 03:13:18
# 7                  Juan Juan      1 2025-04-26 03:13:13
# 8                Nanda Nanda      5 2025-04-26 03:12:47
# 9                 Riko Ricko      5 2025-04-26 03:12:18
#
#                                              content
# 0                        game rajelas, moonton janck
# 1  Knph sich sekarang mh sering erorr mobile lege...
# 2  game ini sangat cocok untuk saya.saya suka ban...
# 3         sudah ngepick hero malah diganti hero lain
# 4  monton ngasih musuh itu yang cupu dikit lah ka...
# 5  makin update makin ga jelas ni game jaringan f...
# 6  minimal punya fitur deteksi jaringan buruk mas...
# 7  JANGAN DOWNLOAD GAME INI JIKA ANDA TIDAK INGIN...
# 8  Game bagus, ini game yg dlu saya mainkan dari ...
# 9                                              bagus

# %%
if 'score' in df_busu.columns:
    Sentiment = []
    for index, row in df_busu.iterrows():
      if row['score'] > 3:
        Sentiment.append('positif')
      else:
        Sentiment.append('negatif')
    df_busu['sentiment'] = Sentiment

# %%
# Memilih hanya kolom 'content dan 'Sentiment'
df_busu = df_busu[['content', 'sentiment']]

# Menampilkan sepuluh baris pertama dari DataFrame yang telah difilter
df_busu.head(10)
# Out:
#                                              content sentiment
# 0                        game rajelas, moonton janck   negatif
# 1  Knph sich sekarang mh sering erorr mobile lege...   positif
# 2  game ini sangat cocok untuk saya.saya suka ban...   positif
# 3         sudah ngepick hero malah diganti hero lain   negatif
# 4  monton ngasih musuh itu yang cupu dikit lah ka...   negatif
# 5  makin update makin ga jelas ni game jaringan f...   negatif
# 6  minimal punya fitur deteksi jaringan buruk mas...   negatif
# 7  JANGAN DOWNLOAD GAME INI JIKA ANDA TIDAK INGIN...   negatif
# 8  Game bagus, ini game yg dlu saya mainkan dari ...   positif
# 9                                              bagus   positif

# %%
df_busu.isnull().sum()
# Out:
# content      0
# sentiment    0
# dtype: int64

# %%
df_busu.shape
# Out:
# (300, 2)

# %%
my_df = df_busu[['content', 'sentiment']]

# %%
my_df.to_csv("mobile_legends_dataset.csv", index = False)

# %% [markdown]
# # **IMPORTING DATASET**
#
# Dataset didapatkan menggunakan teknik web scraping dari website google playstore. Disini saya menggunakan library pandas untuk menampilkan dan membaca dataset.

# %%
import string

data = pd.read_csv('mobile_legends_dataset.csv', sep=',', encoding='latin1')
data.head(10)
# Out:
#                                              content sentiment
# 0                        game rajelas, moonton janck   negatif
# 1  Knph sich sekarang mh sering erorr mobile lege...   positif
# 2  game ini sangat cocok untuk saya.saya suka ban...   positif
# 3         sudah ngepick hero malah diganti hero lain   negatif
# 4  monton ngasih musuh itu yang cupu dikit lah ka...   negatif
# 5  makin update makin ga jelas ni game jaringan f...   negatif
# 6  minimal punya fitur deteksi jaringan buruk mas...   negatif
# 7  JANGAN DOWNLOAD GAME INI JIKA ANDA TIDAK INGIN...   negatif
# 8  Game bagus, ini game yg dlu saya mainkan dari ...   positif
# 9                                              bagus   positif

# %% [markdown]
# **Proses Cleaning Data**

# %%
# Proses case folding
def casefolding(Content):
  Content = Content.lower()
  return Content
data['content'] = data['content'].apply(casefolding)
data.head(10)
# Out:
#                                              content sentiment
# 0                        game rajelas, moonton janck   negatif
# 1  knph sich sekarang mh sering erorr mobile lege...   positif
# 2  game ini sangat cocok untuk saya.saya suka ban...   positif
# 3         sudah ngepick hero malah diganti hero lain   negatif
# 4  monton ngasih musuh itu yang cupu dikit lah ka...   negatif
# 5  makin update makin ga jelas ni game jaringan f...   negatif
# 6  minimal punya fitur deteksi jaringan buruk mas...   negatif
# 7  jangan download game ini jika anda tidak ingin...   negatif
# 8  game bagus, ini game yg dlu saya mainkan dari ...   positif
# 9                                              bagus   positif

# %%
# proses cleansing remove regex (cleansing) seperti tanda baca dan angka angka
import re
import string
def cleansing(Content):
  # Menghapus semua angka dari teks
  Content = re.sub(r'\d+', '', Content)
  # Menghapus semua tanda baca dari teks
  Content = Content.translate(str.maketrans('', '', string.punctuation))
  # Menghapus semua karakter selain huruf dan spasi
  Content = re.sub(r'[^a-zA-Z\s]', '', Content)
  # Menghapus spasi di awal dan akhir teks
  Content = Content.strip(" ")
  # Menghapus simbol tambahan seperti ?, |, $, ., !, _, :, ", ), (, -, +, , dari teks
  Content = re.sub(r'[?|$|.|!_:")(-+,]', '', Content)
  # Mengganti beberapa spasi berturut-turut menjadi satu spasi
  Content = re.sub('\s+', ' ', Content)
  return Content
data['content'] = data['content'].apply(cleansing)
data.head(10)
# Out:
#                                              content sentiment
# 0                         game rajelas moonton janck   negatif
# 1  knph sich sekarang mh sering erorr mobile lege...   positif
# 2  game ini sangat cocok untuk sayasaya suka bang...   positif
# 3         sudah ngepick hero malah diganti hero lain   negatif
# 4  monton ngasih musuh itu yang cupu dikit lah ka...   negatif
# 5  makin update makin ga jelas ni game jaringan f...   negatif
# 6  minimal punya fitur deteksi jaringan buruk mas...   negatif
# 7  jangan download game ini jika anda tidak ingin...   negatif
# 8  game bagus ini game yg dlu saya mainkan dari s...   positif
# 9                                              bagus   positif

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

from nltk.tokenize import word_tokenize
#NLIK word tokenize
def word_tokenize_wrapper(text):
  return word_tokenize(text)
data['content'] = data['content'].apply(word_tokenize_wrapper)
data.head(10)
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
#                                              content sentiment
# 0                    [game, rajelas, moonton, janck]   negatif
# 1  [knph, sich, sekarang, mh, sering, erorr, mobi...   positif
# 2  [game, ini, sangat, cocok, untuk, sayasaya, su...   positif
# 3  [sudah, ngepick, hero, malah, diganti, hero, l...   negatif
# 4  [monton, ngasih, musuh, itu, yang, cupu, dikit...   negatif
# 5  [makin, update, makin, ga, jelas, ni, game, ja...   negatif
# 6  [minimal, punya, fitur, deteksi, jaringan, bur...   negatif
# 7  [jangan, download, game, ini, jika, anda, tida...   negatif
# 8  [game, bagus, ini, game, yg, dlu, saya, mainka...   positif
# 9                                            [bagus]   positif

# %%
# Membaca file CSV untuk kata normalisasi
normalizad_word = pd.read_csv("mobile_legends_dataset.csv")

# Membuat dictionary untuk kata-kata yang dinormalisasi
normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1]

# Fungsi untuk normalisasi kata dalam dokumen
def normalizad_term(document):
    # Pastikan dokumen adalah string, dan split menjadi kata-kata
    if isinstance(document, str):
        words = document.split()
        # Normalisasi setiap kata jika ada dalam dictionary
        normalized_words = [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in words]
        return ' '.join(normalized_words)  # Gabungkan kembali menjadi string
    return document  # Jika bukan string, kembalikan apa adanya

# Terapkan fungsi normalisasi pada kolom 'content'
data = pd.read_csv("mobile_legends_dataset.csv")
data['content'] = data['content'].apply(normalizad_term)

# Tampilkan hanya kolom 'content' dari 10 data pertama
print(data['content'].head(10))
# Out:
# 0                          game rajelas, moonton janck
# 1    Knph sich sekarang mh sering erorr mobile lege...
# 2    game ini sangat cocok untuk saya.saya suka ban...
# 3           sudah ngepick hero malah diganti hero lain
# 4    monton ngasih musuh itu yang cupu dikit lah ka...
# 5    makin update makin ga jelas ni game jaringan f...
# 6    minimal punya fitur deteksi jaringan buruk mas...
# 7    JANGAN DOWNLOAD GAME INI JIKA ANDA TIDAK INGIN...
# 8    Game bagus, ini game yg dlu saya mainkan dari ...
# 9                                              positif
# Name: content, dtype: object
# <ipython-input-19-b4ac71b55e9e>:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[0] not in normalizad_word_dict:
# <ipython-input-19-b4ac71b55e9e>:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   normalizad_word_dict[row[0]] = row[1]

# %%
import nltk
import pandas as pd

# Download stopwords bahasa Indonesia dan Inggris
nltk.download('stopwords')
from nltk.corpus import stopwords

# Membaca dataset
data = pd.read_csv("mobile_legends_dataset.csv")

# Fungsi untuk menghapus stopword
def stopword_removal(content):
    # Gabungkan stopwords bahasa Indonesia dan Inggris
    filtering = stopwords.words('indonesian') + stopwords.words('english')

    # Lakukan filter untuk menghapus stopwords
    filtered_content = [word for word in content.split() if word.lower() not in filtering]
    return ' '.join(filtered_content)

# Terapkan fungsi stopword_removal hanya pada kolom 'content'
data['content'] = data['content'].apply(stopword_removal)

# Tampilkan 10 data pertama dari kolom 'content' saja
print(data['content'].head(10))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 0                          game rajelas, moonton janck
# 1    Knph sich mh erorr mobile legend nya normal ja...
# 2                game cocok saya.saya suka banget game
# 3                            ngepick hero diganti hero
# 4    monton ngasih musuh cupu dikit kayak gitu gk g...
# 5    update ga ni game jaringan full lag, ga geraki...
# 6    minimal fitur deteksi jaringan buruk jaringan ...
# 7                       DOWNLOAD GAME ODGJ,GILA,STRESS
# 8    Game bagus, game yg dlu mainkan 2017 smpe skrg...
# 9                                                bagus
# Name: content, dtype: object

# %% [markdown]
# # **Proses Stemming dan Membuat file data baru (dataset yang sudah dibersihkan melalui proses NLTK)**

# %%
# Install Sastrawi package
# !pip install Sastrawi

import pandas as pd
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Fungsi untuk stemming
def stemming(content):
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()

    # Pisahkan konten menjadi kata-kata jika itu string
    if isinstance(content, str):
        words = content.split()
        stemmed_words = [stemmer.stem(word) for word in words]  # Stem setiap kata
        return ' '.join(stemmed_words)  # Gabungkan kembali menjadi string
    return content  # Jika bukan string, kembalikan apa adanya

# Membaca data CSV
data = pd.read_csv("mobile_legends_dataset.csv")

# Terapkan fungsi stemming hanya pada kolom 'content'
data['content'] = data['content'].apply(stemming)

# Menghapus baris kosong pada kolom 'content' setelah proses stemming
data_clean = data[data['content'].str.strip() != '']

# Simpan hasil ke file CSV
data_clean.to_csv('ml_cleandataset.csv', index=False)

# Tampilkan data bersih (hanya kolom 'content') tanpa nomor baris
print(data_clean['content'].to_string(index=False))
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
#                         game rajelas moonton janck
# knph sich sekarang mh sering erorr mobile legen...
# game ini sangat cocok untuk saya saya suka bang...
#           sudah ngepick hero malah ganti hero lain
# monton ngasih musuh itu yang cupu dikit lah kal...
# makin update makin ga jelas ni game jaring full...
# minimal punya fitur deteksi jaring buruk masa j...
# jangan download game ini jika anda tidak ingin ...
# game bagus ini game yg dlu saya main dari 2017 ...
#                                              bagus
#                                     gw suka ngeleg
#             tolong dalam matchmaking lebih di adil
# game haram tiap main nemu tim ampas mlu gk sesu...
#                                  hapus dark sistem
# tiap 2 match menang abistu di kasi dark sistem ...
# kenapa bug tidak dapat masuk matchmaking padaha...
#        moonton kalahh terus aku jadi malas main ml
# gamenya bagus untuk battlefield sudah cukup adi...
#                       bisa isi waktu senggang saya
#                                               gfee
# game ini jadi teman sejak lama aku suka banget ...
# moga cepat nuklir amerika game tidak laku negar...
# rate game china ini turun drastisssss layak sii...
# we monton aku dah instal ml kok di suruh instal...
# game yang bagus bagi kalang anak muda tapi tolo...
# game nya bagus tapi kenapa cuma msalah ngechat ...
# game gk layak di mainin main solo susah push ra...
# banyak anomali bnyak dark sistem kasih tim ga e...
#                               enak dan hero mantap
# tolong kait masalah jaring untuk segera baik ka...
#                                     game nya bagus
# saya sudah main 4 tahun saya bentar lagi mitik ...
#                                game yg sangat seru
#                                           jembottt
# baguss banget tapi suka ngelek tapi baguss pada...
# bangzat game ankijing masa gw ga main bulan buk...
# bagus banget ak suka sama game ny tapi ap det n...
#                                       bagus banget
#            aku suka main ini aku udah capai master
# game ini sangat buruk di kasih tim yang bgs cum...
#                                  b aja  jlk ni gem
# untuk saat ini 2 dulu karna banyak main yang ti...
#                                              bagus
# makasih yah moonton nggak kasih dark system ter...
# tolong dong di baru saya tidak bisa rilog jadi ...
# kalo ngasi team ngotak dikit anjg cape anjg moo...
#                              kasih hoki kalo gacha
# game gk jelas dapat tim high rank mentok honor ...
#                          kalah menang kalah menang
#                                 bagus gw suka bgt
# lumayan jugaa suka bikin emosi player nya toxic...
# aneh sistem lu tiap mau naik 1 bintang aja wala...
#                               busuk kalah mulu aku
# game buruk telah main sekali terus main yang du...
# di tinggal bentar langsung afk kocak banget monton
# untuk gamenya bagus bagus aja tapi mes tolong t...
#       game nya bagus dan sangat enak pas di mainin
#   game kont ada aja dark sistem lu moonton moonton
#      banyak drak sistem banyak bag dan drak sistem
# banyak bug nya masa aku cuma stuck di lobby ngg...
#                                          jawa hama
#                                  sangat senang kan
#                                             mantap
#                                      game nya seru
# game nya asik tapi banyak hama hama dan dark si...
#                                    musuh nya susah
#                    terimakasih untuk kalah 20 kali
#                    game nya kaya tai game burikkkk
# kalo lu ngasih gw dark system mulu montroll gw ...
#                                sangat seru boss ku
# gem ini sangat bagus sangat laris namun sayang ...
#                         jaring tolong di baik lagi
# game cukup bagus tapi tolong la ini ma masa say...
# masa tiba logout pas lagi di in game malah afk ...
#         skin elit ngasih tim dark sistem elit huhh
#   bantuu naikk rankk donggg jangann naikk turunnnn
# game tolol mending gk usah main ini game dapet ...
# moonton tolong kasih tim bot sampe aku ke legen...
# alam ranked kasih tim yg sengaja kalah bukan ju...
#                                   aku top 1 zilong
# gamenya keren tapi tim nya gak dukung tolong di...
#                                              bagus
# gem apa kek gin anjir ga sesuatu sama tim lawan...
#                 mobile lenged sekrang sangat bagus
#                                         game rusak
# apa guwa main musuh keras terus tim lembek mau ...
#                               game gk ikhlas kntll
# game bagus panjang sejarah bolak balik instal g...
# game jancokkkkk  moonton asu jgn rame in game i...
# game nya pas mau main ngeleg padahal jaring ku ...
# saya baru naik legend abis itu sya main lagi da...
# gin min kalo ngasih musuh itu yang pake logika ...
# gamenya bagus dan gak buat bosan seru bgt bnyk ...
#                   game nya bagus banyak skin bagus
#                                             mantap
# main game seru tapi saya di kasih dark sistem m...
#                                             mantap
#                                              bagus
# benerin lagi jaring nya banyak yang ganggu game...
#                                  gamenya seru bget
#                                     bug nya banyak
#                        game nya bagus etapi bo ong
# main ini sangat bagus andai saja main ini main ...
# ah lama males main ml ping w hijau bagus wifi j...
# game ml adalah game yang paling seru dan senang...
# seruu bos main kadang neng kadang jengkel klo d...
# saya kasih rating 1 karena gw kena bug gak bisa...
#                                          gem rusak
# bagus bangett lagi tapi lama lama jadi susah mu...
#                                        game sampah
# tim dapat dark sistem los strek 27 win 2 pesan ...
#                                         mules bgtt
#               gaenak nya seru banget buru dwonload
#     heh gw udah ngegendong napa kasih coklat lawak
#                                       bagus banget
# suka ngeleg loginnya juga suka lama hp ku hampi...
# monton system konyol kalau solo rank dapetnya p...
#                                 kurang drak sistem
# tolong dong ini kenapa saya tidak bisa masuk ya...
# gamenya asik tapi tolong baik bug gameplay nya ...
# saran saya jangan main ini game kalo kamu derit...
# bagus sih gamenya tapi coba banyakin skin yang ...
#                                      bagus dan oke
#                                              mntap
#                              unbalance battle team
#                              main ini sangat bagus
# gw kecewa sama monton ini gw gak di bolehin dow...
# jangan ada tim beda banget tim mush jung nya mo...
#                                        agak ngeleg
# sistem gameplay nya yg buat kita candu main ml ...
# di kasih tim fomo terus dongo cape ah males mai...
#                                   main sangat seru
# jaringane bongko lek ndlogok og monton i ngangg...
#                                               seru
#                                   bagus banget ini
# game nya seru grafik juga bagus tapi ada satu y...
#                                        sangat seru
# game nya baru donlowd tapi kualitas nya jelek h...
#                                               ciko
#                                              bagus
# kami kurang puas dgn layan moonton karena di le...
# game lol server di benerin mls gw di bacotin mu...
# moonton saya main game untuk ngilangin tres lah...
# gamenya ngasih tim saya bot trus seperti saya p...
# kalo afk yang ngejalanin itu siapa gw belum afk...
#            mantap aku rank nya udah mytick imortal
#                                  matchmaking rusak
#                              bagus banget game nya
#                                 kurang imbang damn
#                    klo menang bisa naikin mood bgs
#                                       tidak bagus
# game stres baru main 3x wins dah yg kalah nya 5...
# ntahlah kadang ga adil tpi kadang free skin jdi...
#                                     jelek atur nya
# sya suka ini gem bagus mudah mudah mudah yg lai...
#                                       gamenya seru
#            apk ini sangat bagus kadang bikin emosi
# gamenya bagus seru cuma pas main kalah mulu dap...
#                                              bagus
#                     gem anj ngasih drk sistem mulu
# moonton ayo aku sering banget ketemu orang yang...
# asli seru banget gk kyk dulu sekarang visual ef...
#                                game nya bagus bett
# bisa tidak admin gloo nya bisa di andal untuk t...
# game faje ngasih tim kaya orang baru maen dapet...
#        match making ga ngotak minimal tara kan lah
# game ny bagus tapi ketika mau main rank kredit ...
# mobile legends adalah game bagus yang pernah sa...
#                           main yg mantap dan hibur
#               ok lah keren bisa nemenin lagi gabut
#                                      lumayan bagus
#                   ml burik mlbb adalah sampah bumi
# game nya enak tapi banyak bug dan juga ngelag n...
# logika kita udah puluh puluh ribu ribu match ra...
#                              tolong jaring di baik
#           game nya baguss gak burik kaya yg belah
#                  banyak bug nya bagus juga ml dulu
# game berat banget gak kayak dulu dan player jug...
#                                              gacor
# kalau mau install aplikasi ini lihat lihat dulu...
#                  game ini sangat recomend utk main
#                         mau login gak bisa di buka
#                  geme ini bagus dan sangat tantang
#     hai saya gina game ini sangat tarik banget deh
#                              oklh gemnya bagus kok
#                                              bagus
#                       sangat mantap sekali gem ini
#                                        sangat seru
#                   walau bikin stress tpi asik cuyy
# anj lu kalo ngasih tim yang bner lah masa gw ls...
#                                 saya suka game ini
#       game nya bagus aku suka soal jadi agak hibur
#                              gamenya sangat baguss
#             bagus sih moonton tapi baik sedikit ya
# game ini dapet drak sistem mulu gak pernah mena...
#                                          game aneh
# baik lagi lah sistem nya banyak orang troll ga ...
# kepada monton tolong yah kalo upgrade itu yg ba...
#                                      sangat senang
# tolong lah moonton musuh jangan yang udah perna...
# apala moonton aku pake wifi loh tapi ngeleg gim...
#                                  seru download aja
# game dark sistem bohong kalau ngasih lawan susa...
#                         min kasih map muda biar hd
# moonton tolong ukur mb download nya di tahan di...
#                 dapat pilih hero maju terus monton
# banyak rol yg sama dalam 1 pertandigan player m...
# kenapaa belakang ini ping tinggi sampei 200 pad...
#                                  kasih menang dong
#          geme enak seruh gampang banget dapat skin
#   saya sangat suka dan saya akhir bisa ngranmaster
#                                      sangat senang
# game ini bagus banget tapi ada iklan di pas tem...
# tolong bagi montoon baik bug jaring gw udh seri...
#                                               seru
#                                          i like it
#                        game haram jangan di mainin
#                                  bagus banget udah
# gw kasih ranting satu ajj ya soal monton gak su...
# tolong baik pingnya hijau nggak lag tapi kenapa...
#                         kasi tim bot musuh ga tara
#   matchmaking ga adil malas gw main nya kalah mulu
#                  monton tolong revamp alpa johnson
# game nya ringan macthmacing main juga imbang  s...
# memang game nya bagus tapi jaring terus ada not...
# mohon ya monton kalo ngasih musuh itu yang pada...
#                                             durgof
# bagus aku suka ga bikin bosen kadang juga bikin...
#                              game nya bagus banget
# game nya sangat seru tetapi butuh memori yang s...
#         buset seru banget gamenya aku sampai candu
#                kenzo dan qianno nagdikasi yan badu
#                               game ini sangat seru
#                                            canduuu
#         kurang bagus sistem kasih team buruk terus
#           bagus game nya walaupun agak stres dikt
#                      sering bikin satu tim sama ai
#                 update event naruto malah bnyk bug
#                        game keren dan bisa offline
#                 game android yang bagus untuk main
#                                             baguss
#                    kapan skin starlaigt miya rilis
#                     games burik banyak drak sistem
# najis ketemu drak sistem gaada lu ngasih gw men...
#                                               seru
#      aku tarik dengan kalah bisa menang bisa kalah
#     banyak player sampah game sampah player sampah
# main udah 10 hari lebih tp tetap aja di temu sa...
#                                      eleleelelelle
#                      mobile legends selalu di hati
# saya ucap terimakasih kepada monton atas ucap s...
# kasih gw menang minton yatim klo ga menangvsamp...
# habis update tambah gak jelas aja ini game nyob...
#              gelo game nya susah tapi candu kunyuk
#                                                  y
# game bayak yang cheat sama banyak bot developer...
#    game ny udah bagus dan tolong hilang darksistem
# masa lagi main tiba sinyal merah udah relog ter...
# moonton rusakkk masa kasih lose treak percuma a...
#                       game hama ga adil game rusak
# mobile legend emang baik aku sampai kasih binta...
#                         hapus dark sistem nya bgst
# game ini sangat jelek jaringannyq basa kalu say...
#                 monton plss lah rangin dark sistem
# udah gk ada temen mabar terlalu sita waktu matc...
# bagus banget aku suka game ini karena aku sanga...
# game nya bagus banget aku lebih suka ml dari pa...
# game nya jelek mending gausah download kalo mau...
#                                              bagus
#                                       gemenya seru
# moonton benerin lah masalah jaring ni saya uda ...
# tolong dong kembali semua game arcade yang dulu...
# game ini sangat sangat seru untuk hilang rasa t...
# pas di awal awal tuh masih takut takut tapi mas...
# tolong dong mintoon kalo kasi tim itu yang sesu...
#                      kalau revamp hero tu yg betul
# waw gamenya sangat buruk bagai teman saya sudah...
#                                 gatau mo ketik apa
# mobile legendaris pasti wifi kalian ngeleg kalo...
#                             kok ga bisa di donlowd
#                      lumayan oke aku kasi bintang
# bug ga jelas pass buka quest event naruto malah...
#                      geme dengan event skin banyak
#                        tidak ramah untuk main solo
#                                         sangat bgs
#               klo udah mau legend mytic kasi kalah
#                     aku bocil epep yg ajar main ml
# saya mau konfirmasi aju banding kenapa telah up...
#                                game bagus dan asik
# makin kesini makin kesana update skin doang sis...
# dapet tim gaje mulu konyol developer ajg yatim ...
# mohon maaf kak tolong lah jangan kasih dark sis...
# tolong montton renk saya baru epik kok turunn t...
#                                      bagus gem nya
#                                         game haram
#                                         game stres
# bagus banget gamenya lain kali banyakin lagi sk...
#                                      game gk jelas
# game rusak player dark system kasih tim jaring ...

# %%
import string
from sklearn.pipeline import make_pipeline
import pandas as pd
import numpy as np
import re

# %%
data_clean = pd.read_csv('ml_cleandataset.csv', encoding='latin1')
data_clean.head(10)
# Out:
#                                              content sentiment
# 0                         game rajelas moonton janck   negatif
# 1  knph sich sekarang mh sering erorr mobile lege...   positif
# 2  game ini sangat cocok untuk saya saya suka ban...   positif
# 3           sudah ngepick hero malah ganti hero lain   negatif
# 4  monton ngasih musuh itu yang cupu dikit lah ka...   negatif
# 5  makin update makin ga jelas ni game jaring ful...   negatif
# 6  minimal punya fitur deteksi jaring buruk masa ...   negatif
# 7  jangan download game ini jika anda tidak ingin...   negatif
# 8  game bagus ini game yg dlu saya main dari 2017...   positif
# 9                                              bagus   positif

# %%
data_clean = data_clean.astype({'sentiment': 'category'})
data_clean = data_clean.astype({'content': 'string'})
data_clean.dtypes
# Out:
# content      string[python]
# sentiment          category
# dtype: object

# %% [markdown]
# # **Proses TF-IDF**

# %%
# PROSES TF IDF
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(data_clean['content'].astype('U'))

tf = TfidfVectorizer()

# Convert NaNs to empty strings
data_clean['content'] = data_clean['content'].fillna('')

text_tf = tf.fit_transform(data_clean['content'])
print(text_tf)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 3589 stored elements and shape (299, 1092)>
#   Coords	Values
#   (0, 327)	0.2229688964451121
#   (0, 845)	0.641647497549446
#   (0, 687)	0.35617671034911313
#   (0, 433)	0.641647497549446
#   (1, 526)	0.24870581366457054
#   (1, 936)	0.24870581366457054
#   (1, 907)	0.2107918793009433
#   (1, 656)	0.24870581366457054
#   (1, 923)	0.38268849069179545
#   (1, 299)	0.24870581366457054
#   (1, 678)	0.17816738625578685
#   (1, 569)	0.17125508497326666
#   (1, 763)	0.3102192091833117
#   (1, 784)	0.16533391191711777
#   (1, 754)	0.2319286304400814
#   (1, 440)	0.15141148986189656
#   (1, 883)	0.16266346118656133
#   (1, 240)	0.24870581366457054
#   (1, 894)	0.12797539025617446
#   (1, 77)	0.2107918793009433
#   (1, 232)	0.12474952682293412
#   (1, 313)	0.14419716077797973
#   (1, 1084)	0.24870581366457054
#   (1, 607)	0.11310534758473179
#   (1, 1025)	0.13147417415536164
#   :	:
#   (296, 104)	0.1849533889185386
#   (296, 328)	0.3029888488638832
#   (296, 550)	0.2685921683631916
#   (296, 1080)	0.3189922351315576
#   (296, 470)	0.33186759259237725
#   (296, 945)	0.3029888488638832
#   (296, 119)	0.43200721442304374
#   (297, 327)	0.3405520870562494
#   (297, 358)	0.6409731512553922
#   (297, 445)	0.6878791284603458
#   (298, 327)	0.10129171569840208
#   (298, 687)	0.16180620103645563
#   (298, 440)	0.1774594141194961
#   (298, 613)	0.23821338628216718
#   (298, 1015)	0.14270342532354646
#   (298, 237)	0.17982554111263507
#   (298, 484)	0.1601621119481188
#   (298, 973)	0.23821338628216718
#   (298, 795)	0.2470552494794953
#   (298, 821)	0.1971228432840124
#   (298, 875)	0.21344039529606523
#   (298, 781)	0.2914916696301136
#   (298, 384)	0.2914916696301136
#   (298, 280)	0.5829833392602272
#   (298, 281)	0.2914916696301136

# %% [markdown]
# # **Proses Cosine Similarity**

# %%
# Import cosine_similiarity metrics
from sklearn.metrics.pairwise import cosine_similarity

# %%
# compute similarity using cosine similarity
cos_sim = cosine_similarity(text_tf, text_tf)
print(cos_sim)
# Out:
# [[1.         0.         0.06849878 ... 0.         0.07593252 0.0802165 ]
#  [0.         1.         0.10524589 ... 0.05975204 0.         0.02686939]
#  [0.06849878 0.10524589 1.         ... 0.06182308 0.10462178 0.03111806]
#  ...
#  [0.         0.05975204 0.06182308 ... 1.         0.         0.        ]
#  [0.07593252 0.         0.10462178 ... 0.         1.         0.03449511]
#  [0.0802165  0.02686939 0.03111806 ... 0.         0.03449511 1.        ]]

# %%
# splitting data
import collections, numpy
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(cos_sim, data_clean['sentiment'], test_size=0.3, random_state=33)
print("Jumlah Data Uji:", X_test.shape)
print("Jumlah Data Latih:", X_train.shape)

# Ensure consistent casing
y_test = y_test.str.upper()
y_train = y_train.str.upper()

pos = (y_test == 'POSITIF').sum()
neg = (y_test == 'NEGATIF').sum()
postrain = (y_train == 'POSITIF').sum()
negtrain = (y_train == 'NEGATIF').sum()
total = pos + neg
print("Jumlah data uji dengan sentimen positif:", pos)
print("Jumlah data uji dengan sentimen negatif:", neg)
print("Jumlah data latih dengan sentimen positif:", postrain)
print("Jumlah data uji dengan sentimen negatif:", negtrain)
data_clean['sentiment'].value_counts()
# Out:
# Jumlah Data Uji: (90, 299)
# Jumlah Data Latih: (209, 299)
# Jumlah data uji dengan sentimen positif: 50
# Jumlah data uji dengan sentimen negatif: 40
# Jumlah data latih dengan sentimen positif: 99
# Jumlah data uji dengan sentimen negatif: 110
# sentiment
# negatif    150
# positif    149
# Name: count, dtype: int64

# %% [markdown]
# # **Perform Algoritma K-Means**

# %%
import pandas as pd
from openpyxl import load_workbook
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# elbow method (teknik untuk menentukan jumlah klaster yang optimal dalam k-means clustering.)
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(text_tf)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Within-cluster sum of squares')
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy.sparse import csr_matrix

# Convert the sparse matrix to a dense array (NumPy array) if you have enough memory
text_tf_dense = text_tf.toarray()

plt.plot(text_tf_dense[:,0], text_tf_dense[:,1], 'ro')
plt.show()

# %% [markdown]
# # **Training the K-Means model on the dataset**

# %%
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(text_tf)

# %%
print(y_kmeans)
# Out:
# [1 4 2 1 1 4 4 1 2 3 1 2 1 1 4 2 1 2 2 1 1 1 1 1 4 1 1 1 1 4 3 2 0 1 2 4 1
#  3 1 4 1 2 3 4 2 1 1 1 1 1 1 1 1 4 1 2 3 1 1 4 1 0 0 0 1 1 2 1 1 0 2 4 2 4
#  1 1 1 1 2 1 4 3 1 1 2 1 1 1 1 3 2 1 3 3 0 2 0 3 4 0 1 1 2 1 2 1 2 1 1 1 1
#  1 0 1 3 1 1 1 2 4 2 1 3 1 1 3 1 1 1 1 4 0 1 0 3 1 0 4 1 3 1 1 2 2 1 1 2 3
#  1 4 3 1 1 1 1 0 1 1 3 1 1 1 3 1 1 4 4 2 2 4 3 1 1 1 4 1 1 1 1 1 2 4 3 2 1
#  3 0 0 1 1 2 1 0 1 1 1 4 1 0 1 1 0 1 1 1 4 1 4 1 1 2 0 3 4 0 1 1 3 1 4 1 2
#  1 1 2 1 1 1 3 0 0 1 0 1 4 1 1 1 2 2 1 1 1 1 0 4 1 1 1 1 2 1 1 1 1 1 1 4 1
#  2 0 1 2 1 1 1 1 4 3 0 1 1 0 1 1 1 1 1 1 4 1 4 1 2 0 1 1 2 3 1 1 1 4 3 1 1
#  1 1 4]

# %% [markdown]
# # **Visualising the clusters**

# %%
import matplotlib.pyplot as plt
from scipy.sparse import csr_matrix

# Assuming text_tf is a csr_matrix
text_tf_dense = text_tf.toarray()

# Use the dense array for plotting
plt.scatter(text_tf_dense[y_kmeans == 0, 0], text_tf_dense[y_kmeans == 0, 1], s=100, c='red', label='cluester_1')
plt.scatter(text_tf_dense[y_kmeans == 1, 0], text_tf_dense[y_kmeans == 1, 1], s=100, c='green', label='cluster_2')
plt.scatter(text_tf_dense[y_kmeans == 2, 0], text_tf_dense[y_kmeans == 2, 1], s=100, c='cyan', label='cluster_3')
plt.scatter(text_tf_dense[y_kmeans == 3, 0], text_tf_dense[y_kmeans == 3, 1], s=100, c='magenta', label='cluster_4')
plt.scatter(text_tf_dense[y_kmeans == 4, 0], text_tf_dense[y_kmeans == 4, 1], s=100, c='blue', label='cluster_5')


# Corrected line for cluster centers
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='yellow', label='centroid')

plt.legend()
plt.show()

# %% [markdown]
# # **Popular Keywords**

# %%
from wordcloud import WordCloud

data = pd.read_csv('mobile_legends_dataset.csv')
data_content = ' '.join(data['content'].dropna().values)
wordcloud = WordCloud(width=800, height=800, background_color='white', min_font_size=10).generate(data_content)
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# Kode tersebut menghasilkan awan kata berdasarkan teks deskripsi dalam kumpulan data, agar dapat menganalisis secara visual kata-kata paling umum yang digunakan dalam fitur ulasan google play store. Semakin besar kata di cloud, semakin sering kata tersebut muncul di kotak deskripsi.

# %% [markdown]
# # **Rata - rata rating untuk setiap sentimen**

# %%
# Buat diagram batang untuk distribusi sentimen
plt.hist(data_clean['sentiment'], bins=3, color='skyblue', edgecolor='black')
plt.xlabel('Sentimen')
plt.ylabel('Jumlah')
plt.title('Distribusi Sentimen Positif dan Negatif')
plt.show()

# Membuat tabel dengan nilai per kategori sentimen
bins = ['POSITIF', 'NEGATIF']  # Kategori sentimen

# Assuming 'sentiment' column contains strings like 'POSITIF', 'NEGATIF'
data_clean['cluster'] = data_clean['sentiment'].str.upper().apply(lambda x: x if x in bins else 'OTHER')

# %% [markdown]
# # **Sentimen Analysis**

# %%
# !pip install textblob
from textblob import TextBlob #Importing the TextBlob library
import matplotlib.pyplot as plt
import pandas as pd

#Classify sentiment
def sentiment_analysis(text):
    analysis = TextBlob(text)
    #threshold for positive and negative sentiments
    if analysis.sentiment.polarity > 0.1:
        return 'Positive'
    elif analysis.sentiment.polarity < -0.1:
        return 'Negative'
    else:
        return 'Neutral'

#Applying sentiment analysis to the review content
reviews = data['sentiment']
reviews_sentiments = reviews.apply(sentiment_analysis)

# Counting the occurrences of each sentiment
sentiment_counts = reviews_sentiments.value_counts()

sentiment_counts.plot(kind='bar', color=['green', 'blue', 'red'], title='Sentiment Analysis of Review Content')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.11/dist-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.11/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (4.67.1)
